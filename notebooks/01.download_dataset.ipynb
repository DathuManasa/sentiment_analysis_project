# %%
import numpy as np

# %%
import json

with open('../artifacts/kaggle.json', 'r') as file:
    data = json.load(file)

# %%
data
# Out:
# {'username': 'manasadathu', 'key': '1f32869e9dbf196e57dc83a3cd7c9370'}

# %%
# !pip install kaggle
# Out:
# Collecting kaggle
#   Downloading kaggle-2.2.3-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: bleach in /home/manasa/Desktop/sentiment_analysis_project/venv/lib/python3.12/site-packages (from kaggle) (6.4.0)
# Collecting jupytext (from kaggle)
#   Downloading jupytext-1.19.4-py3-none-any.whl.metadata (15 kB)
# Collecting kagglesdk<1.0,>=0.1.30 (from kaggle)
#   Downloading kagglesdk-0.1.34-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: packaging in /home/manasa/Desktop/sentiment_analysis_project/venv/lib/python3.12/site-packages (from kaggle) (26.2)
# Collecting protobuf (from kaggle)
#   Downloading protobuf-7.35.1-cp310-abi3-manylinux2014_x86_64.whl.metadata (595 bytes)
# Requirement already satisfied: python-dateutil in /home/manasa/Desktop/sentiment_analysis_project/venv/lib/python3.12/site-packages (from kaggle) (2.9.0.post0)
# Collecting python-dotenv (from kaggle)
#   Downloading python_dotenv-1.2.2-py3-none-any.whl.metadata (27 kB)
# Collecting python-slugify (from kaggle)
#   Downloading python_slugify-8.0.4-py2.py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: requests in /home/manasa/Desktop/sentiment_analysis_project/venv/lib/python3.12/site-packages (from kaggle) (2.34.2)
# Requirement already satisfied: tqdm in /home/manasa/Desktop/sentiment_analysis_project/venv/lib/python3.12/site-packages (from kaggle) (4.69.0)
# Requirement already satisfied: urllib3>=1.15.1 in /home/manasa/Desktop/sentiment_analysis_project/venv/lib/python3.12/site-packages (from kaggle) (2.7.0)
# Requirement already satisfied: webencodings in /home/manasa/Desktop/sentiment_analysis_project/venv/lib/python3.12/site-packages (from bleach->kaggle) (0.5.1)
# Collecting markdown-it-py>=1.0 (from jupytext->kaggle)
#   Downloading markdown_it_py-4.2.0-py3-none-any.whl.metadata (7.4 kB)
# Collecting mdit-py-plugins (from jupytext->kaggle)
#   Downloading mdit_py_plugins-0.6.1-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: nbformat in /home/manasa/Desktop/sentiment_analysis_project/venv/lib/python3.12/site-packages (from jupytext->kaggle) (5.10.4)
# Requirement already satisfied: pyyaml in /home/manasa/Desktop/sentiment_analysis_project/venv/lib/python3.12/site-packages (from jupytext->kaggle) (6.0.3)
# Collecting mdurl~=0.1 (from markdown-it-py>=1.0->jupytext->kaggle)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: fastjsonschema>=2.15 in /home/manasa/Desktop/sentiment_analysis_project/venv/lib/python3.12/site-packages (from nbformat->jupytext->kaggle) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in /home/manasa/Desktop/sentiment_analysis_project/venv/lib/python3.12/site-packages (from nbformat->jupytext->kaggle) (4.26.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/manasa/Desktop/sentiment_analysis_project/venv/lib/python3.12/site-packages (from nbformat->jupytext->kaggle) (5.9.1)
# Requirement already satisfied: traitlets>=5.1 in /home/manasa/Desktop/sentiment_analysis_project/venv/lib/python3.12/site-packages (from nbformat->jupytext->kaggle) (5.15.1)
# Requirement already satisfied: attrs>=22.2.0 in /home/manasa/Desktop/sentiment_analysis_project/venv/lib/python3.12/site-packages (from jsonschema>=2.6->nbformat->jupytext->kaggle) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/manasa/Desktop/sentiment_analysis_project/venv/lib/python3.12/site-packages (from jsonschema>=2.6->nbformat->jupytext->kaggle) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/manasa/Desktop/sentiment_analysis_project/venv/lib/python3.12/site-packages (from jsonschema>=2.6->nbformat->jupytext->kaggle) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /home/manasa/Desktop/sentiment_analysis_project/venv/lib/python3.12/site-packages (from jsonschema>=2.6->nbformat->jupytext->kaggle) (2026.6.3)
# Requirement already satisfied: platformdirs>=2.5 in /home/manasa/Desktop/sentiment_analysis_project/venv/lib/python3.12/site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat->jupytext->kaggle) (4.10.1)
# Requirement already satisfied: typing-extensions>=4.4.0 in /home/manasa/Desktop/sentiment_analysis_project/venv/lib/python3.12/site-packages (from referencing>=0.28.4->jsonschema>=2.6->nbformat->jupytext->kaggle) (4.16.0)
# Requirement already satisfied: six>=1.5 in /home/manasa/Desktop/sentiment_analysis_project/venv/lib/python3.12/site-packages (from python-dateutil->kaggle) (1.17.0)
# Collecting text-unidecode>=1.3 (from python-slugify->kaggle)
#   Downloading text_unidecode-1.3-py2.py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/manasa/Desktop/sentiment_analysis_project/venv/lib/python3.12/site-packages (from requests->kaggle) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /home/manasa/Desktop/sentiment_analysis_project/venv/lib/python3.12/site-packages (from requests->kaggle) (3.18)
# Requirement already satisfied: certifi>=2023.5.7 in /home/manasa/Desktop/sentiment_analysis_project/venv/lib/python3.12/site-packages (from requests->kaggle) (2026.6.17)
# Downloading kaggle-2.2.3-py3-none-any.whl (111 kB)
# Downloading kagglesdk-0.1.34-py3-none-any.whl (247 kB)
# Downloading jupytext-1.19.4-py3-none-any.whl (170 kB)
# Downloading markdown_it_py-4.2.0-py3-none-any.whl (91 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading mdit_py_plugins-0.6.1-py3-none-any.whl (66 kB)
# Downloading protobuf-7.35.1-cp310-abi3-manylinux2014_x86_64.whl (327 kB)
# Downloading python_dotenv-1.2.2-py3-none-any.whl (22 kB)
# Downloading python_slugify-8.0.4-py2.py3-none-any.whl (10 kB)
# Downloading text_unidecode-1.3-py2.py3-none-any.whl (78 kB)
# Installing collected packages: text-unidecode, python-slugify, python-dotenv, protobuf, mdurl, markdown-it-py, kagglesdk, mdit-py-plugins, jupytext, kaggle
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10/10 [kaggle]━━  9/10 [kaggle]t]]
# Successfully installed jupytext-1.19.4 kaggle-2.2.3 kagglesdk-0.1.34 markdown-it-py-4.2.0 mdit-py-plugins-0.6.1 mdurl-0.1.2 protobuf-7.35.1 python-dotenv-1.2.2 python-slugify-8.0.4 text-unidecode-1.3

# %%
import os
os.environ['KAGGLE_USERNAME']=data['username']
os.environ['KAGGLE_KEY']=data['key']

# %%
from kaggle.api.kaggle_api_extended import KaggleApi
api=KaggleApi()
api.authenticate()

# %%
api.dataset_download_files('dineshpiyasamara/sentiment-analysis-dataset',path='../artifacts')
# Out:
# Dataset URL: https://www.kaggle.com/datasets/dineshpiyasamara/sentiment-analysis-dataset

# %%
import zipfile

with zipfile.ZipFile('../artifacts/sentiment-analysis-dataset.zip', 'r') as zip_ref:
    zip_ref.extractall('../artifacts/')
